# %% [markdown]
# # Seaborn ve Matplotlib ile SQL'de Düzenlenmiş Dataset Çalışması

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/abdullahyunus/Desktop/Python Çalışmaları/datasets/Realestatenumericv.csv')
data.head()
# Out:
#         town  sum_of_sales_amount
# 0  Greenwich         3.178950e+10
# 1   Stamford         2.414154e+10
# 2   Westport         1.280660e+10
# 3    Norwalk         1.277310e+10
# 4  Fairfield         1.113678e+10

# %%
data.info
# Out:
# <bound method DataFrame.info of           town  sum_of_sales_amount
# 0    Greenwich         3.178950e+10
# 1     Stamford         2.414154e+10
# 2     Westport         1.280660e+10
# 3      Norwalk         1.277310e+10
# 4    Fairfield         1.113678e+10
# ..         ...                  ...
# 164   Eastford         9.583415e+07
# 165    Chaplin         9.075135e+07
# 166   Hartland         8.865556e+07
# 167   Scotland         6.866358e+07
# 168      Union         4.794801e+07
#
# [169 rows x 2 columns]>

# %%
data['town']
# Out:
# 0      Greenwich
# 1       Stamford
# 2       Westport
# 3        Norwalk
# 4      Fairfield
#          ...
# 164     Eastford
# 165      Chaplin
# 166     Hartland
# 167     Scotland
# 168        Union
# Name: town, Length: 169, dtype: object

# %%
type(data['sum_of_sales_amount'])
# Out:
# pandas.core.series.Series

# %%
a1=data['town'].tolist()
a1
# Out:
# ['Greenwich',
#  'Stamford',
#  'Westport',
#  'Norwalk',
#  'Fairfield',
#  'Darien',
#  'New Canaan',
#  'Danbury',
#  'Bridgeport',
#  'West Hartford',
#  'Milford',
#  'New Haven',
#  'Ridgefield',
#  'Hartford',
#  'Glastonbury',
#  'Hamden',
#  'Waterbury',
#  'Stratford',
#  'Wilton',
#  'Shelton',
#  'Trumbull',
#  'Manchester',
#  'Rocky Hill',
#  'Wallingford',
#  'Farmington',
#  'Newtown',
#  'Southington',
#  'Meriden',
#  'Bristol',
#  'Avon',
#  'Middletown',
#  'Guilford',
#  'Madison',
#  'Weston',
#  'New Britain',
#  'New Milford',
#  'Groton',
#  'Windsor',
#  'West Haven',
#  'Simsbury',
#  'Cheshire',
#  'Enfield',
#  'Branford',
#  'Newington',
#  'East Hartford',
#  'Stonington',
#  'South Windsor',
#  'Brookfield',
#  'Southbury',
#  'North Haven',
#  'Monroe',
#  'East Lyme',
#  'East Haven',
#  'Torrington',
#  'Norwich',
#  'Bloomfield',
#  'Bethel',
#  'Wethersfield',
#  'Orange',
#  'Vernon',
#  'Old Saybrook',
#  'Waterford',
#  'New London',
# ...

# %%
a2=data['sum_of_sales_amount'].tolist()
a2
# Out:
# [31789498747.0,
#  24141539469.0,
#  12806596086.0,
#  12773104961.0,
#  11136784058.0,
#  8952146943.0,
#  8308046361.0,
#  7064948698.0,
#  6610049018.0,
#  6384373480.0,
#  5592226064.0,
#  5255626746.0,
#  5248626794.0,
#  4505944083.0,
#  4424839750.0,
#  4333908964.0,
#  4281243672.0,
#  4223006189.0,
#  4222550013.0,
#  4217572688.0,
#  4079103399.0,
#  3984757115.0,
#  3823463278.0,
#  3399447998.0,
#  3359783628.0,
#  3309599030.0,
#  3218791738.0,
#  3067597813.0,
#  3047926333.0,
#  2989181752.0,
#  2899648379.0,
#  2789203261.0,
#  2785128115.0,
#  2690159931.0,
#  2664226256.0,
#  2624113449.0,
#  2618728288.0,
#  2565137903.0,
#  2557471467.0,
#  2505932455.0,
#  2484146484.0,
#  2422516949.0,
#  2390970720.0,
#  2308681145.0,
#  2301104093.0,
#  2282582331.0,
#  2271434752.0,
#  2180071125.0,
#  2171135606.0,
#  2159851226.0,
#  2103608165.0,
#  2021716489.0,
#  1948480836.0,
#  1911116347.0,
#  1880784970.0,
#  1793918580.0,
#  1754334685.0,
#  1744302411.0,
# ...

# %%
plt.figure(figsize = (30,24))
plt.pie(a2, labels=a1, autopct = '%2.1f%%')
plt.show()
